# %%
import sys

sys.path.append('../src')
from models import Brownian, Vicsek

# %%
Brownian().record(path='../videos/brownian.mp4', show=True)
# Out:
# brownian: 100%|██████████| 500/500 [00:04<00:00, 102.88it/s]
# <video controls  width="500"  height="500">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
Vicsek().record(path='../videos/vicsek.mp4', show=True)
# Out:
# vicsek: 100%|██████████| 500/500 [00:07<00:00, 68.27it/s]
# <video controls  width="500"  height="500">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
